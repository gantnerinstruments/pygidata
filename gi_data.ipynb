# %% [markdown]
# ### Notebook for various API testing

# %%
from time import sleep
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Buffer

# %%
import time
from uuid import UUID
from gimodules.gi_data.dataclient import GIDataClient

BASE = "http://10.1.50.36:8090"


client = GIDataClient(BASE)

src = client.list_buffer_sources()[0]

vars = client.list_stream_variables(src.id)[:2]
selectors = [(v.sid, v.id) for v in vars]

for i in range(0, 2):
    df = client.fetch_buffer(selectors, start_ms=-5000, end_ms=0)
    time.sleep(1)
    print(df.head())
# Out:
# 2025-07-09 14:29:49,857 - gimodules.gi_data.infra.http - DEBUG - Request: GET http://10.1.50.36:8090/buffer/structure/sources | Params: None | Payload: None
# 2025-07-09 14:29:49,866 - gimodules.gi_data.infra.http - DEBUG - Response: 200 | Content-Length: 763
# 2025-07-09 14:29:49,867 - gimodules.gi_data.infra.http - DEBUG - Request: GET http://10.1.50.36:8090/buffer/structure/sources/0/variables | Params: None | Payload: None
# 2025-07-09 14:29:49,877 - gimodules.gi_data.infra.http - DEBUG - Response: 200 | Content-Length: 6496
# 2025-07-09 14:29:49,884 - gimodules.gi_data.infra.http - DEBUG - Request: POST http://10.1.50.36:8090/buffer/data | Params: None | Payload: <present>
# 2025-07-09 14:29:49,888 - gimodules.gi_data.infra.http - DEBUG - Response: 200 | Content-Length: 638
# 2025-07-09 14:29:50,920 - gimodules.gi_data.infra.http - DEBUG - Request: POST http://10.1.50.36:8090/buffer/data | Params: None | Payload: <present>
# 2025-07-09 14:29:50,920 - gimodules.gi_data.infra.http - DEBUG - Response: 200 | Content-Length: 638
#                                      ac338e24-c45b-11ec-98b0-309c23c751bf  \
# time
# 2025-07-09 11:25:04+00:00                                          1314.0
# 2025-07-09 11:25:04.099999905+00:00                                1314.0
# 2025-07-09 11:25:04.200000048+00:00                                1314.0
# 2025-07-09 11:25:04.299999952+00:00                                1314.0
# 2025-07-09 11:25:04.400000095+00:00                                1314.0
#
#                                      fa309824-38b4-11ed-9455-6c4b9078238e
# time
# 2025-07-09 11:25:04+00:00                                             0.0
# 2025-07-09 11:25:04.099999905+00:00                                   0.0
# 2025-07-09 11:25:04.200000048+00:00                                   0.0
# 2025-07-09 11:25:04.299999952+00:00                                   0.0
# 2025-07-09 11:25:04.400000095+00:00                                   0.0
#                                      ac338e24-c45b-11ec-98b0-309c23c751bf  \
# time
# 2025-07-09 11:25:05+00:00                                          1314.0
# 2025-07-09 11:25:05.099999905+00:00                                1314.0
# 2025-07-09 11:25:05.200000048+00:00                                1314.0
# 2025-07-09 11:25:05.299999952+00:00                                1314.0
# 2025-07-09 11:25:05.400000095+00:00                                1314.0
#
#                                      fa309824-38b4-11ed-9455-6c4b9078238e
# time
# 2025-07-09 11:25:05+00:00                                             0.0
# 2025-07-09 11:25:05.099999905+00:00                                   0.0
# 2025-07-09 11:25:05.200000048+00:00                                   0.0
# 2025-07-09 11:25:05.299999952+00:00                                   0.0
# 2025-07-09 11:25:05.400000095+00:00                                   0.0

# %%
import time
from uuid import UUID
from gimodules.gi_data.dataclient import GIDataClient

BASE = "http://10.1.50.36:8090"


client = GIDataClient(BASE)

client.list_buffer_sources()

# %% [markdown]
# ### Websocket

# %%
def subscribe_publish():
    import asyncio
    from uuid import UUID
    from gimodules.gi_data.dataclient import GIDataClient
    from random import random

    client = GIDataClient("http://10.1.50.36:8090")


    vids = [UUID(m["Id"]) for m in client.list_variables()[:4]]

    async def live_stream():
        async for tick in client.stream_online(vids, interval_ms=10000, on_change=True):
            #print("tick:", tick)
            # Variable has to be Output or Input/Output
            await client.publish_online({vids[3]: random()})

    asyncio.run(live_stream())
subscribe_publish()
